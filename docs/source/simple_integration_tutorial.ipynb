# %% [markdown]
# # MindAffect BCI: 3. Running Custom Presentation
#
# ***Complete the first run and Simple Presentation tutorial before starting this one.***
#
# This notebook runs a full BCI using the custom presentation module made in the [Simple Presentation Tutorial](simple_presentation_tutorial.ipynb). To do this we first start the Hub, Acquisition driver, and the Decoder. For more information on these components and why we need them please consult the [First Run Tutorial](first_run.ipyn).

# %%
# Import the mindaffectBCI decoder and other required modules. 
# %load_ext autoreload
# %autoreload 2
# %gui qt
import mindaffectBCI.decoder
from multiprocessing import Process
from time import sleep

# %% [markdown]
# ## Start the Hub

# %%
#--------------------------- HUB ------------------------------
# start the utopia-hub process
from mindaffectBCI.decoder import startUtopiaHub
hub = Process(target=startUtopiaHub.run, daemon=True)
hub.start()

# %% [markdown]
# ## Start the Acquisition driver
#
# **Do not forget to change the acq_args as explained in the first run tutorial!**

# %%
# start the ganglion acquisation process
# Using brainflow for the acquisation driver.  
#  the brainflowargs are kwargs passed to BrainFlowInputParams
#  so change the board_id and other args to use other boards
from mindaffectBCI.examples.acquisation import utopia_brainflow
acq_args =dict(board_id=1, serial_port='com4') # connect to the ganglion
acquisation = Process(target=utopia_brainflow.run, kwargs=acq_args, daemon=True)
acquisation.start()
# wait for driver to startup -- N.B. NEEDED!!
sleep(1)

# %% [markdown]
# ## Start the Decoder

# %%
# start the decoder process, wih default args for noise-tagging
from mindaffectBCI.decoder import decoder
decoder = Process(target=decoder.mainloop, kwargs=dict(
        stopband=[[45,65],[0,3],[25,-1]],
        out_fs=100,
        evtlabs=["re","fe"],
        tau_ms=450,
        calplots=True,
        predplots=False
    ), daemon=True)
decoder.start()

# %% [markdown]
# ## Make sure everything is running

# %%
# check all is running?
print("Hub running {}".format(hub.is_alive()))
print("Acquisation running {}".format(acquisation.is_alive()))
print("Decoder running {}".format(decoder.is_alive()))
# Out:
# Hub running True
# Acquisation running True
# Decoder running True

# %% [markdown]
# ## Run the Custom Presentation
#
# We run our custom presentation module by first importing and then running it.

# %%
# import and run the presentation
from mindaffectBCI.examples.presentation import minimal_presentation

minimal_presentation.run()
# Out:
# waitFor: 120
# .........................................................................................................................
# .Start Cal: 0/2 tgtidx=1
# tgtidx=1
# .flicker: 60 frames, tgt 1
# highlight: tgtidx=1 nframes=60
# ***************...............***************................
# 1.wait
# flicker: 60 frames, tgt -1
# highlight: tgtidx=-1 nframes=60
# .............................................................
# 2.stim, tgt:1
# flicker: 240 frames, tgt 1
# *.*..*.*.*.**.*.*..**.*..*.**..**.*.*.*.*.*..*.*.*.*.**.*.*.*.*..*.**.*.*.*.*.*.*.*..**..*.*.*.*.*.*.**..**..**..**..*.*.*.*.**.*..*.*.*.**.*.*..**.*..*.**..**.*.*.*.*.*..*.*.*.*.**.*.*.*.*..*.**.*.*.*.*.*.*.*..**..*.*.*.*.*.*.**..**..**..**
# 3.wait
# flicker: 60 frames, tgt -1
# highlight: tgtidx=-1 nframes=60
# .............................................................
#
# Start Cal: 1/2 tgtidx=0
# tgtidx=0
# .flicker: 60 frames, tgt 0
# highlight: tgtidx=0 nframes=60
# ***************...............***************................
# 1.wait
# flicker: 60 frames, tgt -1
# highlight: tgtidx=-1 nframes=60
# .............................................................
# 2.stim, tgt:0
# flicker: 240 frames, tgt 0
# .*.**.*.*.*.*..**.*.*..**..**.*..**..*.*.**.*.*..**..**..**.*..**.*.*.*.*..**..*.*.**.*..**..**..*.*.*.**.*..**....*.*.*.*.*.*.*.**.*.*.*.*..**.*.*..**..**.*..**..*.*.**.*.*..**..**..**.*..**.*.*.*.*..**..*.*.**.*..**..**..*.*.*.**.*..**....
# 3.wait
# flicker: 60 frames, tgt -1
# highlight: tgtidx=-1 nframes=60
# .............................................................
#
#
# waitFor: 900
# .....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# .Start Pred: 0/10
# tgtidx=-1
# ..2.stim, tgt:-1
# flicker: 600 frames, tgt -1
#  with selection
# ................................................Pred:P(80) PREDICTEDTARGETPROB 746547199 Yest=0 Perr=0.250000
# .........................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# 3.feedback
# 4260ms pred:-1 sel:0  x
# .
# Start Pred: 1/10
# tgtidx=-1
# ..2.stim, tgt:-1
# flicker: 600 frames, tgt -1
#  with selection
# .........................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# 3.feedback
# 3298ms pred:-1 sel:0  x
# .
# Start Pred: 2/10
# tgtidx=-1
# ..2.stim, tgt:-1
# flicker: 600 frames, tgt -1
#  with selection
# .........................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# 3.feedback
# 3385ms pred:-1 sel:0  x
# .
# Start Pred: 3/10
# tgtidx=-1
# ..2.stim, tgt:-1
# flicker: 600 frames, tgt -1
#  with selection
# .........................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# 3.feedback
# 3268ms pred:-1 sel:0  x
# .
# Start Pred: 4/10
# tgtidx=-1
# ..2.stim, tgt:-1
# flicker: 600 frames, tgt -1
#  with selection
# .........................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# 3.feedback
# 3452ms pred:-1 sel:0  x
# .
# Start Pred: 5/10
# tgtidx=-1
# ..2.stim, tgt:-1
# flicker: 600 frames, tgt -1
#  with selection
# .........................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# 3.feedback
# 3453ms pred:-1 sel:0  x
# .
# Start Pred: 6/10
# tgtidx=-1
# ..2.stim, tgt:-1
# flicker: 600 frames, tgt -1
#  with selection
# .........................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# 3.feedback
# 3233ms pred:-1 sel:0  x
# .
# Start Pred: 7/10
# tgtidx=-1
# ..2.stim, tgt:-1
# flicker: 600 frames, tgt -1
#  with selection
# .........................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# 3.feedback
# 2885ms pred:-1 sel:0  x
# .
# Start Pred: 8/10
# tgtidx=-1
# ..2.stim, tgt:-1
# flicker: 600 frames, tgt -1
#  with selection
# .........................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# 3.feedback
# 2583ms pred:-1 sel:0  x
# .
# Start Pred: 9/10
# tgtidx=-1
# ..2.stim, tgt:-1
# flicker: 600 frames, tgt -1
#  with selection
# .........................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# 3.feedback
# 2552ms pred:-1 sel:0  x
# .
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-deb63b1d9c8c> in <module>
#       2 from mindaffectBCI.examples.presentation import minimal_presentation
#       3
# ----> 4 minimal_presentation.run()
#
# AttributeError: module 'mindaffectBCI.examples.presentation.minimal_presentation' has no attribute 'run'
